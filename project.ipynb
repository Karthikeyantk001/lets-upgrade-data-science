# %%
import pandas as pd

# %% [markdown]
# #1. Read the dataset.

# %%
pubg=pd.read_csv("pubg - Dr. Darshan Ingle.csv")

# %% [markdown]
# #2. Check the datatype of all the columns.

# %%
pubg.dtypes
# Out:
# Id                  object
# groupId             object
# matchId             object
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %% [markdown]
# #3. Find the summary of all the numerical columns and write your findings about it.

# %%
pubg.describe()
# Out:
#             assists        boosts  ...   winPoints  winPlacePerc
# count  10000.000000  10000.000000  ...  10000.0000  10000.000000
# mean       0.234600      1.088500  ...    609.3440      0.469926
# std        0.575149      1.703279  ...    739.7924      0.304508
# min        0.000000      0.000000  ...      0.0000      0.000000
# 25%        0.000000      0.000000  ...      0.0000      0.200000
# 50%        0.000000      0.000000  ...      0.0000      0.458300
# 75%        0.000000      2.000000  ...   1495.0000      0.735100
# max        7.000000     18.000000  ...   1863.0000      1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# Findings:
#
#
# *   We can easily get the overview of the data using this function
# *   It gives count , mean ,minimum and maximum values of each column of the data set
# *   Finaly we can easily summarise data in this way..

# %% [markdown]
# #4. The average person kills how many players?
#
# Avearge person kills 0.913400

# %% [markdown]
# #5. 99% of people have how many kills?

# %%
print(pubg['kills'].quantile(0.99))
# Out:
# 7.0

# %% [markdown]
# #6. The most kills ever recorded are how much?
#
# 35

# %% [markdown]
# #7. Print all the columns of the dataframe.

# %%
pubg.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %% [markdown]
# #8. Comment on distribution of the match's duration. Use seaborn.

# %%
import seaborn as sns

sns.distplot( pubg["matchDuration"]);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Comments :
# *  It shows that most of players plays the match in time duration between  1350-1400
#
# * Very few people only crosses 2000
# * Till 1000 most of hte people  are alive

# %% [markdown]
# #9. Comment on distribution of the walk distance. Use seaborn.

# %%
sns.distplot( pubg["walkDistance"]);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# when walk distance increases the count decreses,..
# that is both are inversely proportional to each other.

# %% [markdown]
# #10. Plot distribution of the match's duration vs walk distance one below the other.

# %%
import matplotlib.pyplot as plt
plt.subplot(211)
plt.plot(pubg["matchDuration"])
plt.title("Match Duration VS WalkDistance")
plt.subplot(212)
plt.plot(pubg["walkDistance"])

# %% [markdown]
# #11. Plot distribution of the match's duration vs walk distance side by side.

# %%
plt.subplot(121)
plt.plot(pubg["matchDuration"])
plt.title("matchDuration VS walkDistance")
plt.subplot(122)
plt.plot(pubg["walkDistance"])

# %% [markdown]
# #12. Pairplot the dataframe. Comment on kills vs damage dealt, Comment on maxPlace vs numGroups.

# %%
sns.pairplot(pubg.head(100))

# %% [markdown]
# #13. How many unique values are there in 'matchType' and what are their counts?

# %%
len(pubg["matchType"].unique())
# Out:
# 14

# %%
pubg["matchType"].value_counts()
# Out:
# squad-fpp           3969
# duo-fpp             2282
# squad               1359
# solo-fpp            1234
# duo                  702
# solo                 386
# normal-squad-fpp      24
# crashfpp              13
# normal-duo-fpp        13
# normal-solo-fpp        8
# normal-squad           4
# flaretpp               3
# crashtpp               2
# flarefpp               1
# Name: matchType, dtype: int64

# %% [markdown]
# #14. Plot a barplot of ‘matchType’ vs 'killPoints'. Write your inferences.

# %%
import matplotlib.pyplot as plt
sns.barplot(x="matchType",y="killPoints",data=pubg)
plt.xticks(rotation=90);

# %% [markdown]
# It shows that normal-duo-fpp having highest kill points

# %% [markdown]
# #15. Plot a barplot of ‘matchType’ vs ‘weaponsAcquired’. Write your inferences.

# %%
sns.barplot(x="matchType",y="weaponsAcquired",data=pubg)
plt.xticks(rotation=90);

# %% [markdown]
# In normal-solo-fpp more weapons were acquired

# %% [markdown]
# #16. Find the Categorical columns.

# %%
pubg.select_dtypes(include=['category']).dtypes
# Out:
# Series([], dtype: object)

# %% [markdown]
# here no catogorical data types

# %% [markdown]
# #17. Plot a boxplot of ‘matchType’ vs ‘winPlacePerc’. Write your inferences.

# %%
sns.boxplot(x="matchType", y="winPlacePerc",data=pubg)
plt.xticks(rotation=90);

# %% [markdown]
# #18. Plot a boxplot of ‘matchType’ vs ‘matchDuration’. Write your inferences.

# %%
sns.boxplot(x="matchType",y="matchDuration",data=pubg)
plt.xticks(rotation=90);

# %% [markdown]
# #19. Change the orientation of the above plot to horizontal.

# %%
sns.boxplot(y="matchType",x="matchDuration",data=pubg)

# %% [markdown]
# #20. Add a new column called ‘KILL’ which contains the sum of following columns viz. headshotKills,teamKills, roadKills.

# %%
kill=pubg["headshotKills"]+pubg["teamKills"]+pubg["roadKills"]

# %%
pubg["KILL"]=kill
pubg
# Out:
#                   Id         groupId  ... winPlacePerc  KILL
# 0     2f262dd9795e60  78437bcd91d40e  ...         0.00     0
# 1     a32847cf5bf34b  85b7ce5a12e10b  ...         0.22     1
# 2     1b1900a9990396  edf80d6523380a  ...         0.86     1
# 3     f589dd03b60bf2  804ab5e5585558  ...         0.35     0
# 4     c23c4cc5b78b35  b3e2cd169ed920  ...         0.07     0
# ...              ...             ...  ...          ...   ...
# 9995  ef4f474acd8e85  2eca2a8391f75d  ...         0.83     0
# 9996  cf0bf82fb4d80e  2eaf2765f93adb  ...         0.72     0
# 9997  a0a31a0b1dcbe1  8d50c64ccc5071  ...         0.21     0
# 9998  f6874657399d69  d31843d7e62ccb  ...         0.24     0
# 9999  90359b0b8f8b0d  61d5b1bb8da43f  ...         0.19     0
#
# [10000 rows x 30 columns]

# %% [markdown]
# #21. Round off column ‘winPlacePerc’ to 2 decimals.

# %%
pubg["winPlacePerc"]=pubg["winPlacePerc"].round(decimals=2)
pubg
# Out:
#                   Id         groupId  ... winPlacePerc  KILL
# 0     2f262dd9795e60  78437bcd91d40e  ...         0.00     0
# 1     a32847cf5bf34b  85b7ce5a12e10b  ...         0.22     1
# 2     1b1900a9990396  edf80d6523380a  ...         0.86     1
# 3     f589dd03b60bf2  804ab5e5585558  ...         0.35     0
# 4     c23c4cc5b78b35  b3e2cd169ed920  ...         0.07     0
# ...              ...             ...  ...          ...   ...
# 9995  ef4f474acd8e85  2eca2a8391f75d  ...         0.83     0
# 9996  cf0bf82fb4d80e  2eaf2765f93adb  ...         0.72     0
# 9997  a0a31a0b1dcbe1  8d50c64ccc5071  ...         0.21     0
# 9998  f6874657399d69  d31843d7e62ccb  ...         0.24     0
# 9999  90359b0b8f8b0d  61d5b1bb8da43f  ...         0.19     0
#
# [10000 rows x 30 columns]

# %% [markdown]
# #22. Take a sample of size 50 from the column damageDealt for 100 times and calculate its mean. Plotit on a histogram and comment on its distribution.

# %%
mean = []

for i in range(100):
  
  for x in range(0,1001,50):
    
    mean1 = pubg['damageDealt'].head(x).mean()
    mean.append(mean1)
 
sns.histplot(data=pubg['damageDealt'], x=mean)
